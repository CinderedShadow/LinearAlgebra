# %%
from matrices import *

def printDescription(s):
    for line in s.splitlines(): 
        print(line)

def cont(n):
    while True:
        cont = input(f"Ready to continue to Section {n}? ")
        cont = cont.lower()
        if "yes" in cont:
            break
        else:
            print("Really?")


print("Welcome to 2tor41, where you can learn about Matrices and Linear Transformations!")

while True:
    start = input("Ready to begin? ")
    start = start.lower()
    if "yes" in start:
        break
    else:
        print("Okay, begin when you are ready.")

section1 = """
Section 1: Introduction

A matrix is a rectangular array of numbers. Each number is called an entry of the matrix.
A vector is a matrix with one row or one column.
A zero vector is a vector where all entries of the vector are zero.

Here is an example of a matrix:

1 2 5 4
2 3 0 6
7 3 8 9

Here is an example of a vector:

1 2 5 4

An m by n (m x n) matrix has m rows and n columns. The matrix example above is a 3 x 4 matrix.

A matrix is square if it has the same amount of rows and columns. Here is an example of a square matrix, which has 4 rows and 4 columns.

1 2 5 4
2 3 0 6
7 3 8 9
3 5 4 1

"""
printDescription(section1)

cont(2)

# Quiz for Dimensions of Matrices

section2 = """
Section 2: Linear Combinations of Sets of Vectors

Matrices and vectors with the same amount of rows and columns can be added by adding entries in the same positions. 

A scalar is a numerical value.
Matrices and vectors can be multiplied by a scalar by multiplying every entry by that scalar. The products are called scalar multiples.

A linear combination of a set of vectors is the sum of specific scalar multiples of the vectors.

A trivial linear combination is a linear combination that represents the zero vector by a sum of vectors, with each vector being multiplied by scalar zero.

A nontrivial linear combination is a linear combination that represents the zero vector by a sum of non-zero scalar multiples of vectors.

A set of vectors is linearly independent if the vectors can only represent the zero vector by a trivial linear combination of those vectors

A set of vectors is linearly dependent if it is possible to represent the zero vector as a nontrivial linear combination of those vectors.

"""
printDescription(section2)

secton3 = ''
printDescription(section3)

def simpleDeterminantQuiz():
    matrix = generateSquareMatrix(2)
    for row in matrix:
        print(row)
    while True:
        determinantAsk = input('What is the determinant of the above matrix? ')
        if not determinantAsk.isdigit():
            print('Invalid input!')
        else:
            determinantAsk = int(determinantAsk)
            if determinantAsk == determinant(matrix):
                print('Correct!')
                break
            else:
                print("Wrong! Try Again!")

simpleDeterminantQuiz()

def matrixMultiplicationQuiz():
    while True:
        rows1, cols1 = random.randint(1, 3), random.randint(1, 3)
        rows2, cols2 = cols1, random.randint(1, 3)
        matrix1 = generateMatrix(rows1, cols1)
        matrix2 = generateMatrix(rows2, cols2)
        print('What is the matrix multiplication of the following matrices?')
        for row in matrix1:
            print(row)
        print('x')
        for row in matrix2:
            print(row)
        correctAnswer = matrixMultiplication(matrix1, matrix2)
        userAnswer = getMatrix()
        """rows3, cols3 = len(answer), len(answer[0])
        output = [['_']*cols3 for row in range(rows3))]
        while True:
            for row in output:
                print(row)
            complete = True
            for row in range(rows3):
                for col in range(cols3):
                    if output[row][col] == '_':
                        complete = False
            if complete:
                break
            else:
                rowInput = int(input('Row: ')) - 1 # for indexing
                colInput = int(input('Column: ')) - 1 # for indexing
                entryInput = int(input('What is the entry? '))
                output[rowInput][colInput] = entryInput"""
        if userAnswer == correctAnswer:
            print('Correct Answer!')
            break
        else:
            print('Try Again!')
            continue

matrixMultiplicationQuiz()
